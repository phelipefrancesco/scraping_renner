# %%
import pandas as pd

# %%
df = pd.read_json('lojas_renner.json')

# %%
df
# Out:
#      UF                   estabelecimento  \
# 0    AC                Shopping Via Verde
# 1    AL         Shopping Iguatemi Maceió
# 2    AL  Shopping Parque Shopping Maceió
# 3    AL             Shopping Pátio Maceió
# 4    AL         Shopping Arapiraca Garden
# ..   ..                               ...
# 380  SP    Loja Avenida Paulista - RENNER
# 381  SP                  Shopping Tamboré
# 382  SP  Shopping Pátio Paulista - RENNER
# 383  SP                    Shopping Light
# 384  TO            Shopping Capim Dourado
#
#                                            endereco numero
# 0                               ESTRADA DA FLORESTA   1707
# 1                             AVENIDA GUSTAVO PAIVA   2990
# 2                  AVENIDA COMENDADOR GUSTAVO PAIVA   5945
# 3                            AVENIDA MENINO MARCELO   3800
# 4                            RUA JOSE LEITE BEZERRA    S/N
# ..                                              ...    ...
# ...

# %%
df.groupby(['UF']).count()
# Out:
#     estabelecimento  endereco  numero
# UF
# AC                1         1       1
# AL                4         4       4
# AM                6         6       6
# AP                1         1       1
# BA               13        13      13
# CE               10        10      10
# DF               10        10      10
# ES               10        10      10
# GO               11        11      11
# MA                6         6       6
# MG               30        30      30
# MS                5         5       5
# MT                7         7       7
# PA                9         9       9
# PB                3         3       3
# PE                9         9       9
# PI                4         4       4
# PR               19        19      19
# RJ               39        39      39
# RN                3         3       3
# RO                1         1       1
# RR                2         2       2
# RS               45        45      45
# ...
